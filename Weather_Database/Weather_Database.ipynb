# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 786

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=40584d6cfa33770ec4872142d430d809'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descriptions = city_weather["weather"][0]["description"]

            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_descriptions})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 2 of Set 1 | codrington
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | cuamba
# Processing Record 5 of Set 1 | skibbereen
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | hambantota
# Processing Record 8 of Set 1 | kamaishi
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | mackenzie
# Processing Record 11 of Set 1 | ayan
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | khatanga
# Processing Record 14 of Set 1 | burnie
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | safaqis
# City not found. Skipping...
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | kidal
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | vyartsilya
# Processing Record 24 of Set 1 | isangel
# Processing Record 25 of Set 1 | jiblah
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | chuy
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | the valley
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | guerrero negro
# Processing Record 35 of Set 1 | adrar
# Processing Record 36 of Set 1 | mar del plata
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | kavieng
# Processing Record 41 of Set 1 | jarjis
# City not found. Skipping...
# Processing Record 42 of Set 1 | denpasar
# Processing Record 43 of Set 1 | durban
# Processing Record 44 of Set 1 | luwuk
# Processing Record 45 of Set 1 | kibaya
# Processing Record 46 of Set 1 | klaksvik
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | goderich
# Processing Record 50 of Set 1 | avarua
# Processing Record 1 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | bandarbeyla
# Processing Record 4 of Set 2 | atasu
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | qasigiannguit
# Processing Record 7 of Set 2 | oksfjord
# Processing Record 8 of Set 2 | kodiak
# Processing Record 9 of Set 2 | walvis bay
# Processing Record 10 of Set 2 | zabol
# Processing Record 11 of Set 2 | hilo
# Processing Record 12 of Set 2 | padang
# Processing Record 13 of Set 2 | atar
# Processing Record 14 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 2 | mehamn
# Processing Record 16 of Set 2 | tasiilaq
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | san mateo del mar
# Processing Record 20 of Set 2 | vardo
# Processing Record 21 of Set 2 | fortuna
# Processing Record 22 of Set 2 | hamilton
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | mudgal
# Processing Record 25 of Set 2 | gamba
# Processing Record 26 of Set 2 | tura
# Processing Record 27 of Set 2 | busselton
# Processing Record 28 of Set 2 | dikson
# Processing Record 29 of Set 2 | mahajanga
# Processing Record 30 of Set 2 | abnub
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | kruisfontein
# Processing Record 33 of Set 2 | amarkantak
# Processing Record 34 of Set 2 | thompson
# Processing Record 35 of Set 2 | westport
# Processing Record 36 of Set 2 | kuusamo
# Processing Record 37 of Set 2 | ierapetra
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | miri
# Processing Record 40 of Set 2 | ostrovnoy
# Processing Record 41 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | grafton
# Processing Record 43 of Set 2 | talas
# Processing Record 44 of Set 2 | chokurdakh
# Processing Record 45 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 2 | avera
# Processing Record 48 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 2 | ponta delgada
# Processing Record 50 of Set 2 | quesnel
# Processing Record 1 of Set 3 | meihekou
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | saint-joseph
# Processing Record 4 of Set 3 | greenfield
# Processing Record 5 of Set 3 | havoysund
# Processing Record 6 of Set 3 | port lincoln
# Processing Record 7 of Set 3 | kholmogory
# Processing Record 8 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 3 | bambous virieux
# Processing Record 10 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 11 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 3 | cabo san lucas
# Processing Record 13 of Set 3 | tekeli
# Processing Record 14 of Set 3 | santa ana
# Processing Record 15 of Set 3 | shangzhi
# Processing Record 16 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 3 | mahebourg
# Processing Record 18 of Set 3 | geraldton
# Processing Record 19 of Set 3 | bandrele
# Processing Record 20 of Set 3 | ust-ilimsk
# Processing Record 21 of Set 3 | santa vitoria do palmar
# Processing Record 22 of Set 3 | luanda
# Processing Record 23 of Set 3 | fort nelson
# Processing Record 24 of Set 3 | saint anthony
# Processing Record 25 of Set 3 | cockburn town
# Processing Record 26 of Set 3 | leningradskiy
# Processing Record 27 of Set 3 | wamba
# Processing Record 28 of Set 3 | saurimo
# Processing Record 29 of Set 3 | mataura
# Processing Record 30 of Set 3 | kupang
# Processing Record 31 of Set 3 | smithers
# Processing Record 32 of Set 3 | arlit
# Processing Record 33 of Set 3 | norman wells
# Processing Record 34 of Set 3 | carlyle
# Processing Record 35 of Set 3 | pleszew
# Processing Record 36 of Set 3 | macau
# Processing Record 37 of Set 3 | peleduy
# Processing Record 38 of Set 3 | natal
# Processing Record 39 of Set 3 | nouadhibou
# Processing Record 40 of Set 3 | mount gambier
# Processing Record 41 of Set 3 | chara
# Processing Record 42 of Set 3 | bredasdorp
# Processing Record 43 of Set 3 | cabra
# Processing Record 44 of Set 3 | te anau
# Processing Record 45 of Set 3 | cap-aux-meules
# Processing Record 46 of Set 3 | marsabit
# Processing Record 47 of Set 3 | maiduguri
# Processing Record 48 of Set 3 | kununurra
# Processing Record 49 of Set 3 | karaton
# Processing Record 50 of Set 3 | poum
# Processing Record 1 of Set 4 | la rioja
# Processing Record 2 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 4 | benguela
# Processing Record 4 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 5 of Set 4 | billings
# Processing Record 6 of Set 4 | ponta do sol
# Processing Record 7 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 8 of Set 4 | old bridge
# Processing Record 9 of Set 4 | derzhavinsk
# Processing Record 10 of Set 4 | buchanan
# Processing Record 11 of Set 4 | chima
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | broome
# Processing Record 14 of Set 4 | kelvington
# Processing Record 15 of Set 4 | taoudenni
# Processing Record 16 of Set 4 | esperance
# Processing Record 17 of Set 4 | longyearbyen
# Processing Record 18 of Set 4 | beyneu
# Processing Record 19 of Set 4 | birao
# Processing Record 20 of Set 4 | brae
# Processing Record 21 of Set 4 | korla
# Processing Record 22 of Set 4 | sao miguel do araguaia
# Processing Record 23 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 24 of Set 4 | ntungamo
# Processing Record 25 of Set 4 | boshnyakovo
# Processing Record 26 of Set 4 | dingle
# Processing Record 27 of Set 4 | borogontsy
# Processing Record 28 of Set 4 | cap malheureux
# Processing Record 29 of Set 4 | mantua
# Processing Record 30 of Set 4 | taltal
# Processing Record 31 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 4 | baiyin
# Processing Record 33 of Set 4 | severo-kurilsk
# Processing Record 34 of Set 4 | ilulissat
# Processing Record 35 of Set 4 | airai
# Processing Record 36 of Set 4 | yakeshi
# Processing Record 37 of Set 4 | provideniya
# Processing Record 38 of Set 4 | port elizabeth
# Processing Record 39 of Set 4 | pevek
# Processing Record 40 of Set 4 | bireun
# Processing Record 41 of Set 4 | nikolskoye
# Processing Record 42 of Set 4 | santa maria
# Processing Record 43 of Set 4 | stilling
# Processing Record 44 of Set 4 | boende
# Processing Record 45 of Set 4 | cochrane
# Processing Record 46 of Set 4 | katherine
# Processing Record 47 of Set 4 | tombouctou
# Processing Record 48 of Set 4 | shimoda
# Processing Record 49 of Set 4 | andradas
# Processing Record 50 of Set 4 | mwene-ditu
# Processing Record 1 of Set 5 | coihaique
# Processing Record 2 of Set 5 | hailar
# Processing Record 3 of Set 5 | blahodatne
# Processing Record 4 of Set 5 | leh
# Processing Record 5 of Set 5 | lixourion
# Processing Record 6 of Set 5 | rocha
# Processing Record 7 of Set 5 | villazon
# Processing Record 8 of Set 5 | lang son
# Processing Record 9 of Set 5 | zhangye
# Processing Record 10 of Set 5 | touros
# Processing Record 11 of Set 5 | ixtapa
# Processing Record 12 of Set 5 | baherden
# Processing Record 13 of Set 5 | cayenne
# Processing Record 14 of Set 5 | diu
# Processing Record 15 of Set 5 | qostanay
# Processing Record 16 of Set 5 | port shepstone
# Processing Record 17 of Set 5 | sorland
# Processing Record 18 of Set 5 | victoria
# Processing Record 19 of Set 5 | sindang
# Processing Record 20 of Set 5 | chapais
# Processing Record 21 of Set 5 | cape town
# Processing Record 22 of Set 5 | carnarvon
# Processing Record 23 of Set 5 | tuktoyaktuk
# Processing Record 24 of Set 5 | cherskiy
# Processing Record 25 of Set 5 | kinanah
# City not found. Skipping...
# Processing Record 26 of Set 5 | trincomalee
# Processing Record 27 of Set 5 | andra
# Processing Record 28 of Set 5 | at-bashi
# Processing Record 29 of Set 5 | huinan
# Processing Record 30 of Set 5 | mouzakion
# City not found. Skipping...
# Processing Record 31 of Set 5 | varhaug
# Processing Record 32 of Set 5 | faya
# Processing Record 33 of Set 5 | chistogorskiy
# Processing Record 34 of Set 5 | vanimo
# Processing Record 35 of Set 5 | kamenka
# Processing Record 36 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 5 | san sebastian
# Processing Record 39 of Set 5 | huntsville
# Processing Record 40 of Set 5 | zhovtneve
# Processing Record 41 of Set 5 | alofi
# Processing Record 42 of Set 5 | barstow
# Processing Record 43 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 44 of Set 5 | hasaki
# Processing Record 45 of Set 5 | moussoro
# Processing Record 46 of Set 5 | east london
# Processing Record 47 of Set 5 | novopavlovka
# Processing Record 48 of Set 5 | vao
# Processing Record 49 of Set 5 | payo
# Processing Record 50 of Set 5 | pochinki
# Processing Record 1 of Set 6 | nizhniy baskunchak
# Processing Record 2 of Set 6 | cozumel
# Processing Record 3 of Set 6 | old road
# City not found. Skipping...
# Processing Record 4 of Set 6 | galle
# Processing Record 5 of Set 6 | marshfield
# Processing Record 6 of Set 6 | weyburn
# Processing Record 7 of Set 6 | calama
# Processing Record 8 of Set 6 | pacific grove
# Processing Record 9 of Set 6 | ca mau
# Processing Record 10 of Set 6 | urambo
# Processing Record 11 of Set 6 | saldanha
# Processing Record 12 of Set 6 | tautira
# Processing Record 13 of Set 6 | palmer
# Processing Record 14 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 15 of Set 6 | saint-philippe
# Processing Record 16 of Set 6 | graaff-reinet
# Processing Record 17 of Set 6 | den helder
# Processing Record 18 of Set 6 | half moon bay
# Processing Record 19 of Set 6 | ribeira grande
# Processing Record 20 of Set 6 | waharoa
# Processing Record 21 of Set 6 | kieta
# Processing Record 22 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 6 | bharatpur
# Processing Record 24 of Set 6 | karakol
# Processing Record 25 of Set 6 | sur
# Processing Record 26 of Set 6 | college
# Processing Record 27 of Set 6 | sitka
# Processing Record 28 of Set 6 | morehead
# Processing Record 29 of Set 6 | beroroha
# Processing Record 30 of Set 6 | huntingdon
# Processing Record 31 of Set 6 | yinchuan
# Processing Record 32 of Set 6 | san quintin
# Processing Record 33 of Set 6 | kachiry
# Processing Record 34 of Set 6 | sjenica
# Processing Record 35 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 6 | saskylakh
# Processing Record 37 of Set 6 | segou
# Processing Record 38 of Set 6 | narsaq
# Processing Record 39 of Set 6 | los llanos de aridane
# Processing Record 40 of Set 6 | cleburne
# Processing Record 41 of Set 6 | prachuap khiri khan
# Processing Record 42 of Set 6 | posse
# Processing Record 43 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 6 | pontevel
# Processing Record 45 of Set 6 | chandigarh
# Processing Record 46 of Set 6 | batagay
# Processing Record 47 of Set 6 | hobyo
# Processing Record 48 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 6 | anadyr
# Processing Record 50 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 1 of Set 7 | erzurum
# Processing Record 2 of Set 7 | mezen
# Processing Record 3 of Set 7 | asaba
# Processing Record 4 of Set 7 | turangi
# Processing Record 5 of Set 7 | clermont
# Processing Record 6 of Set 7 | sorochinsk
# Processing Record 7 of Set 7 | chokwe
# Processing Record 8 of Set 7 | kaitangata
# Processing Record 9 of Set 7 | saint-augustin
# Processing Record 10 of Set 7 | tessalit
# Processing Record 11 of Set 7 | daxian
# City not found. Skipping...
# Processing Record 12 of Set 7 | svetlaya
# Processing Record 13 of Set 7 | hofn
# Processing Record 14 of Set 7 | wenatchee
# Processing Record 15 of Set 7 | tuatapere
# Processing Record 16 of Set 7 | tari
# Processing Record 17 of Set 7 | nalut
# Processing Record 18 of Set 7 | umm lajj
# Processing Record 19 of Set 7 | sabang
# Processing Record 20 of Set 7 | orlik
# Processing Record 21 of Set 7 | parintins
# Processing Record 22 of Set 7 | fairbanks
# Processing Record 23 of Set 7 | north bend
# Processing Record 24 of Set 7 | porangatu
# Processing Record 25 of Set 7 | sao jose da coroa grande
# Processing Record 26 of Set 7 | xunchang
# Processing Record 27 of Set 7 | kenai
# Processing Record 28 of Set 7 | clyde river
# Processing Record 29 of Set 7 | beidao
# Processing Record 30 of Set 7 | bairiki
# Processing Record 31 of Set 7 | mpika
# Processing Record 32 of Set 7 | pitimbu
# Processing Record 33 of Set 7 | auki
# Processing Record 34 of Set 7 | husavik
# Processing Record 35 of Set 7 | ambilobe
# Processing Record 36 of Set 7 | marysville
# Processing Record 37 of Set 7 | ust-nera
# Processing Record 38 of Set 7 | sicamous
# Processing Record 39 of Set 7 | cabedelo
# Processing Record 40 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 7 | slave lake
# Processing Record 42 of Set 7 | portland
# Processing Record 43 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 7 | nieuw amsterdam
# Processing Record 45 of Set 7 | ulaangom
# Processing Record 46 of Set 7 | shiyan
# Processing Record 47 of Set 7 | kalabo
# Processing Record 48 of Set 7 | sioux lookout
# Processing Record 49 of Set 7 | wabana
# Processing Record 50 of Set 7 | ileza
# Processing Record 1 of Set 8 | tokonou
# Processing Record 2 of Set 8 | bolshoye murashkino
# Processing Record 3 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 8 | katsuura
# Processing Record 5 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 6 of Set 8 | bengkulu
# Processing Record 7 of Set 8 | rudnogorsk
# Processing Record 8 of Set 8 | iqaluit
# Processing Record 9 of Set 8 | stykkisholmur
# Processing Record 10 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 8 | san luis
# Processing Record 12 of Set 8 | san rafael
# Processing Record 13 of Set 8 | dunedin
# Processing Record 14 of Set 8 | vila
# Processing Record 15 of Set 8 | prince rupert
# Processing Record 16 of Set 8 | trelew
# Processing Record 17 of Set 8 | flin flon
# Processing Record 18 of Set 8 | malakal
# Processing Record 19 of Set 8 | saint george
# Processing Record 20 of Set 8 | mucuri
# Processing Record 21 of Set 8 | minsk
# Processing Record 22 of Set 8 | nehoiu
# Processing Record 23 of Set 8 | glenwood springs
# Processing Record 24 of Set 8 | sharjah
# Processing Record 25 of Set 8 | saquena
# Processing Record 26 of Set 8 | santiago del estero
# Processing Record 27 of Set 8 | tucupita
# Processing Record 28 of Set 8 | mogadishu
# Processing Record 29 of Set 8 | ukiah
# Processing Record 30 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 8 | mexico
# Processing Record 32 of Set 8 | bjornevatn
# Processing Record 33 of Set 8 | san andres
# Processing Record 34 of Set 8 | kaspiyskiy
# Processing Record 35 of Set 8 | juneau
# Processing Record 36 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 8 | inverell
# Processing Record 38 of Set 8 | bom jesus da lapa
# Processing Record 39 of Set 8 | rapar
# Processing Record 40 of Set 8 | windhoek
# Processing Record 41 of Set 8 | jieshou
# Processing Record 42 of Set 8 | paranhos
# Processing Record 43 of Set 8 | ancud
# Processing Record 44 of Set 8 | benjamin constant
# Processing Record 45 of Set 8 | motygino
# Processing Record 46 of Set 8 | kalomo
# City not found. Skipping...
# Processing Record 47 of Set 8 | teya
# Processing Record 48 of Set 8 | pimentel
# Processing Record 49 of Set 8 | icod de los vinos
# Processing Record 50 of Set 8 | virginia beach
# Processing Record 1 of Set 9 | lavrentiya
# Processing Record 2 of Set 9 | vila velha
# Processing Record 3 of Set 9 | raudeberg
# Processing Record 4 of Set 9 | ballina
# Processing Record 5 of Set 9 | grand gaube
# Processing Record 6 of Set 9 | pisco
# Processing Record 7 of Set 9 | west wendover
# Processing Record 8 of Set 9 | luis correia
# Processing Record 9 of Set 9 | maracaju
# Processing Record 10 of Set 9 | srandakan
# Processing Record 11 of Set 9 | novoagansk
# Processing Record 12 of Set 9 | namibe
# Processing Record 13 of Set 9 | sinnamary
# Processing Record 14 of Set 9 | yuci
# Processing Record 15 of Set 9 | constitucion
# Processing Record 16 of Set 9 | yatou
# Processing Record 17 of Set 9 | kendari
# Processing Record 18 of Set 9 | gori
# Processing Record 19 of Set 9 | nesna
# Processing Record 20 of Set 9 | nandurbar
# Processing Record 21 of Set 9 | bindura
# Processing Record 22 of Set 9 | chabahar
# Processing Record 23 of Set 9 | bembibre
# Processing Record 24 of Set 9 | nipawin
# Processing Record 25 of Set 9 | comodoro rivadavia
# Processing Record 26 of Set 9 | sidney
# Processing Record 27 of Set 9 | baykit
# Processing Record 28 of Set 9 | vallenar
# Processing Record 29 of Set 9 | kulhudhuffushi
# Processing Record 30 of Set 9 | simbahan
# Processing Record 31 of Set 9 | berdigestyakh
# Processing Record 32 of Set 9 | yerbogachen
# Processing Record 33 of Set 9 | nampula
# Processing Record 34 of Set 9 | lufkin
# Processing Record 35 of Set 9 | coihueco
# Processing Record 36 of Set 9 | mosquera
# Processing Record 37 of Set 9 | nanortalik
# Processing Record 38 of Set 9 | ambon
# Processing Record 39 of Set 9 | katangli
# Processing Record 40 of Set 9 | saint-pierre
# Processing Record 41 of Set 9 | kulu
# Processing Record 42 of Set 9 | tromso
# Processing Record 43 of Set 9 | lagoa
# Processing Record 44 of Set 9 | bar harbor
# Processing Record 45 of Set 9 | labuhan
# Processing Record 46 of Set 9 | lyuban
# Processing Record 47 of Set 9 | hazleton
# Processing Record 48 of Set 9 | meulaboh
# Processing Record 49 of Set 9 | turayf
# Processing Record 50 of Set 9 | savonlinna
# Processing Record 1 of Set 10 | kota belud
# Processing Record 2 of Set 10 | vila franca do campo
# Processing Record 3 of Set 10 | dolores
# Processing Record 4 of Set 10 | flinders
# Processing Record 5 of Set 10 | unai
# Processing Record 6 of Set 10 | acapulco
# Processing Record 7 of Set 10 | arman
# Processing Record 8 of Set 10 | kalmunai
# Processing Record 9 of Set 10 | khatassy
# Processing Record 10 of Set 10 | lively
# Processing Record 11 of Set 10 | praia da vitoria
# Processing Record 12 of Set 10 | san cristobal
# Processing Record 13 of Set 10 | terekli-mekteb
# Processing Record 14 of Set 10 | santa rosa
# Processing Record 15 of Set 10 | itoman
# Processing Record 16 of Set 10 | deputatskiy
# Processing Record 17 of Set 10 | eyl
# Processing Record 18 of Set 10 | constantine
# Processing Record 19 of Set 10 | kampene
# Processing Record 20 of Set 10 | rena
# Processing Record 21 of Set 10 | banda aceh
# Processing Record 22 of Set 10 | filadelfia
# Processing Record 23 of Set 10 | kuching
# Processing Record 24 of Set 10 | solton
# Processing Record 25 of Set 10 | osoyoos
# Processing Record 26 of Set 10 | likasi
# Processing Record 27 of Set 10 | rundu
# Processing Record 28 of Set 10 | vestmannaeyjar
# Processing Record 29 of Set 10 | souillac
# Processing Record 30 of Set 10 | hendek
# Processing Record 31 of Set 10 | rawson
# Processing Record 32 of Set 10 | byron bay
# Processing Record 33 of Set 10 | anloga
# Processing Record 34 of Set 10 | manakara
# Processing Record 35 of Set 10 | linchuan
# City not found. Skipping...
# Processing Record 36 of Set 10 | mulchen
# Processing Record 37 of Set 10 | kismayo
# Processing Record 38 of Set 10 | chaa-khol
# City not found. Skipping...
# Processing Record 39 of Set 10 | chitrakonda
# Processing Record 40 of Set 10 | luderitz
# Processing Record 41 of Set 10 | mount isa
# Processing Record 42 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 43 of Set 10 | kosh-agach
# Processing Record 44 of Set 10 | bantou
# Processing Record 45 of Set 10 | pavlodar
# Processing Record 46 of Set 10 | alirajpur
# Processing Record 47 of Set 10 | catuday
# Processing Record 48 of Set 10 | kizlyar
# Processing Record 49 of Set 10 | elk plain
# Processing Record 50 of Set 10 | weston
# Processing Record 1 of Set 11 | shu
# Processing Record 2 of Set 11 | angoche
# Processing Record 3 of Set 11 | trairi
# Processing Record 4 of Set 11 | warmbad
# Processing Record 5 of Set 11 | marrakesh
# Processing Record 6 of Set 11 | kavaratti
# Processing Record 7 of Set 11 | terrace bay
# Processing Record 8 of Set 11 | aldan
# Processing Record 9 of Set 11 | karanja
# Processing Record 10 of Set 11 | yumen
# Processing Record 11 of Set 11 | kahului
# Processing Record 12 of Set 11 | buraydah
# Processing Record 13 of Set 11 | xicotencatl
# Processing Record 14 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 11 | panara
# Processing Record 16 of Set 11 | dunyapur
# Processing Record 17 of Set 11 | dire
# Processing Record 18 of Set 11 | owase
# Processing Record 19 of Set 11 | manaure
# Processing Record 20 of Set 11 | champerico
# Processing Record 21 of Set 11 | zlutice
# Processing Record 22 of Set 11 | monterey
# Processing Record 23 of Set 11 | high prairie
# Processing Record 24 of Set 11 | margate
# Processing Record 25 of Set 11 | hervey bay
# Processing Record 26 of Set 11 | elk river
# Processing Record 27 of Set 11 | miandrivazo
# Processing Record 28 of Set 11 | shenzhen
# Processing Record 29 of Set 11 | karaman
# Processing Record 30 of Set 11 | yar-sale
# Processing Record 31 of Set 11 | conceicao da barra
# Processing Record 32 of Set 11 | novobiryusinskiy
# Processing Record 33 of Set 11 | kuito
# Processing Record 34 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 11 | saint-paul
# Processing Record 36 of Set 11 | oussouye
# Processing Record 37 of Set 11 | cortez
# Processing Record 38 of Set 11 | estelle
# Processing Record 39 of Set 11 | kampot
# Processing Record 40 of Set 11 | halifax
# Processing Record 41 of Set 11 | omsukchan
# Processing Record 42 of Set 11 | zaragoza
# Processing Record 43 of Set 11 | bereda
# Processing Record 44 of Set 11 | tilichiki
# Processing Record 45 of Set 11 | puerto escondido
# Processing Record 46 of Set 11 | haines junction
# Processing Record 47 of Set 11 | ambositra
# Processing Record 48 of Set 11 | totma
# Processing Record 49 of Set 11 | nyimba
# Processing Record 50 of Set 11 | castilho
# Processing Record 1 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 12 | bajil
# Processing Record 3 of Set 12 | porosozero
# Processing Record 4 of Set 12 | san isidro
# Processing Record 5 of Set 12 | ustye
# Processing Record 6 of Set 12 | namatanai
# Processing Record 7 of Set 12 | solnechnyy
# Processing Record 8 of Set 12 | neiafu
# Processing Record 9 of Set 12 | iberia
# Processing Record 10 of Set 12 | dubbo
# Processing Record 11 of Set 12 | monte patria
# Processing Record 12 of Set 12 | obzor
# Processing Record 13 of Set 12 | nyurba
# Processing Record 14 of Set 12 | manicore
# Processing Record 15 of Set 12 | port blair
# Processing Record 16 of Set 12 | batagay-alyta
# Processing Record 17 of Set 12 | worthington
# Processing Record 18 of Set 12 | velur
# Processing Record 19 of Set 12 | burica
# City not found. Skipping...
# Processing Record 20 of Set 12 | hailey
# Processing Record 21 of Set 12 | rio grande
# Processing Record 22 of Set 12 | abalak
# Processing Record 23 of Set 12 | garm
# City not found. Skipping...
# Processing Record 24 of Set 12 | sao filipe
# Processing Record 25 of Set 12 | itapuranga
# Processing Record 26 of Set 12 | iki-burul
# Processing Record 27 of Set 12 | aklavik
# Processing Record 28 of Set 12 | tucuman
# Processing Record 29 of Set 12 | mpongwe
# Processing Record 30 of Set 12 | altay
# Processing Record 31 of Set 12 | akom
# Processing Record 32 of Set 12 | kodinsk
# Processing Record 33 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 12 | ahipara
# Processing Record 35 of Set 12 | portoferraio
# Processing Record 36 of Set 12 | tazovskiy
# Processing Record 37 of Set 12 | qui nhon
# Processing Record 38 of Set 12 | omboue
# Processing Record 39 of Set 12 | stoicanesti
# Processing Record 40 of Set 12 | milkovo
# Processing Record 41 of Set 12 | naraini
# Processing Record 42 of Set 12 | chifeng
# Processing Record 43 of Set 12 | pitiquito
# Processing Record 44 of Set 12 | wewak
# Processing Record 45 of Set 12 | cordoba
# Processing Record 46 of Set 12 | ponnani
# Processing Record 47 of Set 12 | nan
# Processing Record 48 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 12 | caucaia
# Processing Record 50 of Set 12 | bolintinu-din-vale
# City not found. Skipping...
# Processing Record 1 of Set 13 | shirgaon
# Processing Record 2 of Set 13 | lerwick
# Processing Record 3 of Set 13 | aden
# Processing Record 4 of Set 13 | benghazi
# Processing Record 5 of Set 13 | launceston
# Processing Record 6 of Set 13 | khoy
# Processing Record 7 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 8 of Set 13 | bara
# Processing Record 9 of Set 13 | borama
# City not found. Skipping...
# Processing Record 10 of Set 13 | alyangula
# Processing Record 11 of Set 13 | pontianak
# Processing Record 12 of Set 13 | svay rieng
# Processing Record 13 of Set 13 | port pirie
# Processing Record 14 of Set 13 | bonthe
# Processing Record 15 of Set 13 | maniitsoq
# Processing Record 16 of Set 13 | katete
# Processing Record 17 of Set 13 | kholm
# Processing Record 18 of Set 13 | aquiraz
# Processing Record 19 of Set 13 | lorengau
# Processing Record 20 of Set 13 | biak
# Processing Record 21 of Set 13 | ekibastuz
# Processing Record 22 of Set 13 | talnakh
# Processing Record 23 of Set 13 | talcahuano
# Processing Record 24 of Set 13 | svencionys
# Processing Record 25 of Set 13 | la ronge
# Processing Record 26 of Set 13 | axim
# Processing Record 27 of Set 13 | bagotville
# Processing Record 28 of Set 13 | honiara
# Processing Record 29 of Set 13 | timra
# Processing Record 30 of Set 13 | doha
# Processing Record 31 of Set 13 | abha
# Processing Record 32 of Set 13 | muswellbrook
# Processing Record 33 of Set 13 | komsomolskiy
# Processing Record 34 of Set 13 | rio gallegos
# Processing Record 35 of Set 13 | nome
# Processing Record 36 of Set 13 | faanui
# Processing Record 37 of Set 13 | kudahuvadhoo
# Processing Record 38 of Set 13 | naze
# Processing Record 39 of Set 13 | belmonte
# Processing Record 40 of Set 13 | henties bay
# Processing Record 41 of Set 13 | suez
# Processing Record 42 of Set 13 | tamale
# Processing Record 43 of Set 13 | demidov
# Processing Record 44 of Set 13 | hualmay
# Processing Record 45 of Set 13 | nemuro
# Processing Record 46 of Set 13 | izhma
# Processing Record 47 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 48 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 13 | hendijan
# City not found. Skipping...
# Processing Record 50 of Set 13 | hit
# Processing Record 1 of Set 14 | madang
# Processing Record 2 of Set 14 | pangkalanbuun
# City not found. Skipping...
# Processing Record 3 of Set 14 | mingaora
# Processing Record 4 of Set 14 | sao geraldo do araguaia
# Processing Record 5 of Set 14 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 6 of Set 14 | dudinka
# Processing Record 7 of Set 14 | maragogi
# Processing Record 8 of Set 14 | helong
# Processing Record 9 of Set 14 | pringsewu
# Processing Record 10 of Set 14 | dakar
# Processing Record 11 of Set 14 | mindelo
# Processing Record 12 of Set 14 | antofagasta
# Processing Record 13 of Set 14 | kisangani
# Processing Record 14 of Set 14 | krasnovishersk
# Processing Record 15 of Set 14 | ligayan
# Processing Record 16 of Set 14 | lincoln
# Processing Record 17 of Set 14 | nantucket
# Processing Record 18 of Set 14 | sept-iles
# Processing Record 19 of Set 14 | coquimbo
# Processing Record 20 of Set 14 | bury saint edmunds
# City not found. Skipping...
# Processing Record 21 of Set 14 | tatarskaya kargala
# Processing Record 22 of Set 14 | cidreira
# Processing Record 23 of Set 14 | bell ville
# Processing Record 24 of Set 14 | pangai
# Processing Record 25 of Set 14 | naftah
# City not found. Skipping...
# Processing Record 26 of Set 14 | merauke
# Processing Record 27 of Set 14 | biryusinsk
# Processing Record 28 of Set 14 | salym
# Processing Record 29 of Set 14 | nanakuli
# Processing Record 30 of Set 14 | lundamo
# Processing Record 31 of Set 14 | pochutla
# Processing Record 32 of Set 14 | kasama
# Processing Record 33 of Set 14 | zhigansk
# City not found. Skipping...
# Processing Record 34 of Set 14 | nuevo celilac
# City not found. Skipping...
# Processing Record 35 of Set 14 | sao joao da barra
# Processing Record 36 of Set 14 | ghanaur
# Processing Record 37 of Set 14 | antalaha
# Processing Record 38 of Set 14 | xuanhua
# Processing Record 39 of Set 14 | nueve de julio
# Processing Record 40 of Set 14 | naryan-mar
# Processing Record 41 of Set 14 | grindavik
# Processing Record 42 of Set 14 | ajdabiya
# Processing Record 43 of Set 14 | kozhva
# Processing Record 44 of Set 14 | northam
# Processing Record 45 of Set 14 | kemin
# Processing Record 46 of Set 14 | tabou
# City not found. Skipping...
# Processing Record 47 of Set 14 | ambanja
# Processing Record 48 of Set 14 | srednekolymsk
# Processing Record 49 of Set 14 | chengde
# Processing Record 50 of Set 14 | black river
# Processing Record 1 of Set 15 | camana
# Processing Record 2 of Set 15 | ladario
# Processing Record 3 of Set 15 | ndende
# Processing Record 4 of Set 15 | itarema
# Processing Record 5 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 15 | necochea
# Processing Record 7 of Set 15 | bela
# Processing Record 8 of Set 15 | asau
# Processing Record 9 of Set 15 | rosario
# Processing Record 10 of Set 15 | muromtsevo
# Processing Record 11 of Set 15 | aguimes
# Processing Record 12 of Set 15 | vila do maio
# Processing Record 13 of Set 15 | marystown
# Processing Record 14 of Set 15 | jalingo
# Processing Record 15 of Set 15 | khislavichi
# Processing Record 16 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 15 | kasongo-lunda
# Processing Record 18 of Set 15 | mbaiki
# Processing Record 19 of Set 15 | lyngseidet
# Processing Record 20 of Set 15 | muros
# Processing Record 21 of Set 15 | drumheller
# Processing Record 22 of Set 15 | bushehr
# Processing Record 23 of Set 15 | adamas
# Processing Record 24 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 15 | djibo
# Processing Record 26 of Set 15 | lima duarte
# Processing Record 27 of Set 15 | vangaindrano
# Processing Record 28 of Set 15 | buzmeyin
# Processing Record 29 of Set 15 | bardiyah
# Processing Record 30 of Set 15 | huadian
# Processing Record 31 of Set 15 | tual
# Processing Record 32 of Set 15 | rio cuarto
# Processing Record 33 of Set 15 | soyo
# Processing Record 34 of Set 15 | batemans bay
# Processing Record 35 of Set 15 | mandalgovi
# Processing Record 36 of Set 15 | bantry
# Processing Record 37 of Set 15 | miyako
# Processing Record 38 of Set 15 | roma
# Processing Record 39 of Set 15 | pundaguitan
# Processing Record 40 of Set 15 | kendal
# Processing Record 41 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 43 of Set 15 | santander jimenez
# Processing Record 44 of Set 15 | lora del rio
# Processing Record 45 of Set 15 | ulladulla
# Processing Record 46 of Set 15 | gorontalo
# Processing Record 47 of Set 15 | vaitape
# Processing Record 48 of Set 15 | jurado
# Processing Record 49 of Set 15 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 50 of Set 15 | viedma
# Processing Record 1 of Set 16 | sakakah
# Processing Record 2 of Set 16 | machilipatnam
# Processing Record 3 of Set 16 | sikeston
# Processing Record 4 of Set 16 | buala
# Processing Record 5 of Set 16 | lakatoro
# Processing Record 6 of Set 16 | kashi
# Processing Record 7 of Set 16 | nuuk
# Processing Record 8 of Set 16 | villa carlos paz
# Processing Record 9 of Set 16 | salem
# Processing Record 10 of Set 16 | caravelas
# Processing Record 11 of Set 16 | tlahualilo
# City not found. Skipping...
# Processing Record 12 of Set 16 | igbo ora
# Processing Record 13 of Set 16 | tsiroanomandidy
# Processing Record 14 of Set 16 | shizunai
# Processing Record 15 of Set 16 | mercedes
# Processing Record 16 of Set 16 | falmouth
# Processing Record 17 of Set 16 | kirovgrad
# Processing Record 18 of Set 16 | scarborough
# Processing Record 19 of Set 16 | gangotri
# City not found. Skipping...
# Processing Record 20 of Set 16 | jutai
# Processing Record 21 of Set 16 | parrita
# Processing Record 22 of Set 16 | lompoc
# Processing Record 23 of Set 16 | naron
# Processing Record 24 of Set 16 | quatre cocos
# Processing Record 25 of Set 16 | puertollano
# Processing Record 26 of Set 16 | logumkloster
# Processing Record 27 of Set 16 | bestobe
# Processing Record 28 of Set 16 | luena
# Processing Record 29 of Set 16 | marabba
# Processing Record 30 of Set 16 | belmopan
# Processing Record 31 of Set 16 | makakilo city
# Processing Record 32 of Set 16 | hof
# Processing Record 33 of Set 16 | lata
# Processing Record 34 of Set 16 | zile
# Processing Record 35 of Set 16 | cairns
# Processing Record 36 of Set 16 | camacha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 713

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Codrington -38.2667  141.9667     57.96        71          43       11.36
# 1     Rikitea -23.1203 -134.9692     73.11        61          58       16.08
# 2      Cuamba -14.8031   36.5372     67.01        61           7        1.70
# 3  Skibbereen  51.5500   -9.2667     50.11        89          23        7.99
# 4      Albany  42.6001  -73.9662     54.36        83           4        1.01
# 5  Hambantota   6.1241   81.1185     86.34        70          20       11.50
# 6    Kamaishi  39.2667  141.8833     74.64        58           4        3.47
# 7  Georgetown   5.4112  100.3354     86.90        79          40        2.30
# 8   Mackenzie  55.2999 -123.1698     59.22        72         100        3.44
# 9        Ayan  56.4500  138.1667     41.58        48          26       21.03
#
#   Country Weather Description
# 0      AU    scattered clouds
# 1      PF       broken clouds
# 2      MZ           clear sky
# 3      IE          few clouds
# 4      US           clear sky
# 5      LK          few clouds
# 6      JP           clear sky
# 7      MY    scattered clouds
# 8      CA     overcast clouds
# 9      RU    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", 
                    "Humidity",  "Cloudiness", "Wind Speed",  "Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Codrington      AU -38.2667  141.9667     57.96        71          43
# 1     Rikitea      PF -23.1203 -134.9692     73.11        61          58
# 2      Cuamba      MZ -14.8031   36.5372     67.01        61           7
# 3  Skibbereen      IE  51.5500   -9.2667     50.11        89          23
# 4      Albany      US  42.6001  -73.9662     54.36        83           4
# 5  Hambantota      LK   6.1241   81.1185     86.34        70          20
# 6    Kamaishi      JP  39.2667  141.8833     74.64        58           4
# 7  Georgetown      MY   5.4112  100.3354     86.90        79          40
# 8   Mackenzie      CA  55.2999 -123.1698     59.22        72         100
# 9        Ayan      RU  56.4500  138.1667     41.58        48          26
#
#    Wind Speed Weather Description
# 0       11.36    scattered clouds
# 1       16.08       broken clouds
# 2        1.70           clear sky
# 3        7.99          few clouds
# 4        1.01           clear sky
# 5       11.50          few clouds
# 6        3.47           clear sky
# 7        2.30    scattered clouds
# 8        3.44     overcast clouds
# 9       21.03    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26728\1574004242.py in <module>
#       3
#       4 # Export the city_data DataFrame into a CSV file
# ----> 5 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
